# %% [markdown]
# # Esterification yield summary
#
# A synthetic notebook for the visual comparison: **bold**, *italic*, `inline code`, a [web link](https://example.com/results) and a [link to a local file](data.json), which prints as plain text.
#
# 1. Weigh the acid
# 2. Add the alcohol
#    - dropwise
#    - at 0 °C
# 3. Reflux for 2 h
#
# | Run | Temperature (°C) | Yield (%) |
# |----:|-----------------:|----------:|
# | 1 | 60 | 71.2 |
# | 2 | 70 | 78.9 |
# | 3 | 80 | 83.4 |
#
# > Yields are isolated yields after column chromatography.

# %%
import statistics

yields = {1: 71.2, 2: 78.9, 3: 83.4}
note = "wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me wrap me "  # far wider than the page, so it must wrap
print(f"mean yield: {statistics.mean(yields.values()):.1f} %")
for run, value in yields.items():
    print(f"run {run}: {value:5.1f} %")
# Out:
# mean yield: 77.8 %
# run 1:  71.2 %
# run 2:  78.9 %
# run 3:  83.4 %

# %%
summary = {"runs": 3, "best": 3, "solvent": "toluene"}
summary
# Out:
# {'runs': 3, 'best': 3, 'solvent': 'toluene'}

# %%
table
# Out:
#    temperature_c  yield_pct
# 1  60  71.2

# %%
show_gradient()

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 1 / 0
# ZeroDivisionError: division by zero

# %%
import sys
print("warning: run 1 is below 75 %", file=sys.stderr)

# %%
for i in range(90):
    print(f"step {i:02d}: pressure {2.0 + i / 100:.2f} bar, conversion {i * 1.1:.1f} %")
# Out:
# step 00: pressure 2.00 bar, conversion 0.0 %
# step 01: pressure 2.01 bar, conversion 1.1 %
# step 02: pressure 2.02 bar, conversion 2.2 %
# step 03: pressure 2.03 bar, conversion 3.3 %
# step 04: pressure 2.04 bar, conversion 4.4 %
# step 05: pressure 2.05 bar, conversion 5.5 %
# step 06: pressure 2.06 bar, conversion 6.6 %
# step 07: pressure 2.07 bar, conversion 7.7 %
# step 08: pressure 2.08 bar, conversion 8.8 %
# step 09: pressure 2.09 bar, conversion 9.9 %
# step 10: pressure 2.10 bar, conversion 11.0 %
# step 11: pressure 2.11 bar, conversion 12.1 %
# step 12: pressure 2.12 bar, conversion 13.2 %
# step 13: pressure 2.13 bar, conversion 14.3 %
# step 14: pressure 2.14 bar, conversion 15.4 %
# step 15: pressure 2.15 bar, conversion 16.5 %
# step 16: pressure 2.16 bar, conversion 17.6 %
# step 17: pressure 2.17 bar, conversion 18.7 %
# step 18: pressure 2.18 bar, conversion 19.8 %
# step 19: pressure 2.19 bar, conversion 20.9 %
# step 20: pressure 2.20 bar, conversion 22.0 %
# ...

# %% [markdown]
# ## Notes in other languages
#
# Überprüfung der Ausbeute · 収率の確認 · проверка выхода · έλεγχος απόδοσης
